# %% [markdown]
# <a href="https://colab.research.google.com/github/Thasyatrish/2602092421/blob/main/sc_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
# Out:
# <ipython-input-7-6b6b9e931396>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1, 3, 3, 5, 2, 2]

# %%
f = interp1d(x,y)

x_lin = np.linspace(0,5,100)
y_lin = f(x_lin)

y_ask = f(3.1)
print (y_ask)
# Out:
# 4.699999999999999

# %%
plt.plot (x,y, 'ob')
plt.plot(x_lin, y_lin, 'b')
plt.plot(3.1,f(3.1),'ro')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

# %matplotlib inline
def divided_diff(x,y):
  '''
  function tto calculate the divided
  differences table
  '''
  n =len(y)
  coef = np.zeros([n, n])
#the first column is y

  coef[:,0]=y

  for j in range(1,n):
    for i in range(n-j):
      coef[i][j]= \
      (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j]-x[i])

  return coef

def newton_poly(coef, x_data, x):

  '''
  evaluate the newton polyminal
  at x
  '''

  n = len(x_data) - 1
  p = coef[n]
  for k in range(1,n+1):
    p = coef[n-k] + (x -x_data[n-k])*p
  return p
# Out:
# <ipython-input-11-ade777c8f394>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
x = np.array ([-5,-1,0,2])
y = np.array ([-2,6,1,3])
# get the divided difference coef
a_s =  divided_diff(x,y)[0,:]

# evaluate on new data points
x_new = np.arange(-5,2.1, .1)
y_new = newton_poly(a_s, x, x_new)

plt.figure(figsize = (12,8))
plt.plot(x,y, 'bo')
plt.plot(x_new, x_new, 'go')
plt.plot(x_new, y_new)

# %%
import numpy as np 
from scipy import optimize 
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

# generate x and y
x = np.linspace(0,1,100)
y = 1 + x + x * np.random.random(len(x))

# assemble matrix A
A = np.vstack([x, np.ones(len(x))]).T

# turn y into a column vector
y =y[:, np.newaxis]

# direct least square regression
alpha = np.dot ((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)
print(alpha)
# Out:
# [[1.47587452]
#  [1.00981409]]
# <ipython-input-13-1c2a0479305c>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
# plot the results
plt.figure(figsize = (10,8))
plt.plot(x,y, 'b')
plt.plot(x, alpha[0]*x + alpha[1], 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pinv = np.linalg.pinv(A)
alpha = pinv.dot(y)
print(alpha)
# Out:
# [[1.47587452]
#  [1.00981409]]

# %%
alpha = np.linalg.lstsq(A, y, rcond=None)[0]
print(alpha)
# Out:
# [[1.47587452]
#  [1.00981409]]

# %%
# generate x and y
x = np.linspace(0,1,101)
y = 1 + x + x * np.random.random(len(x))

def func(x, a, b):
  y = a*x + b
  return y

alpha = optimize.curve_fit(func, xdata = x, ydata = y)[0]
print(alpha)

# plot the result
plt.figure(figsize = (10,8))
plt.plot(x,y, 'b')
plt.plot(x, alpha[0]*x + alpha[1], 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show
# Out:
# [1.56805317 0.98825465]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1, 3, 3, 5, 2, 2]

# %%
f = CubicSpline(x, y, bc_type= 'natural')

x_cub = np.linspaces(0,5,101)
y_cub = f(x_cub)

y_ask = f(2.9)
print(y_ask)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-18cd86c86531> in <cell line: 3>()
#       1 f = CubicSpline(x, y, bc_type= 'natural')
#       2
# ----> 3 x_cub = np.linspaces(0,5,101)
#       4 y_cub = f(x_cub)
#       5
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     313             return Tester
#     314
# --> 315         raise AttributeError("module {!r} has no attribute "
#     316                              "{!r}".format(__name__, attr))
#     317
#
# AttributeError: module 'numpy' has no attribute 'linspaces'

# %%
plt.plot(x, y, 'bo')
plt.plot(x_cub, y_cub, 'b')
plt.plot (2.9, f(2.9), 'ro')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-79eea536667d> in <cell line: 2>()
#       1 plt.plot(x, y, 'bo')
# ----> 2 plt.plot(x_cub, y_cub, 'b')
#       3 plt.plot (2.9, f(2.9), 'ro')
#       4 plt.show()
#
# NameError: name 'x_cub' is not defined
